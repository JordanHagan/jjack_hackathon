# %%
import pandas as pd

# %%
df = pd.read_pickle('data/dataframe.pkl')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.reset_index(drop=True)
# Out:
#                       Date Autoclave Total Feed Autoclave Level  \
# 0       01-Jan-15 00:00:00          282.4959412     72.69987488
# 1       01-Jan-15 00:30:00          282.2843323     69.61645508
# 2       01-Jan-15 01:00:00          282.3558044     71.25708008
# 3       01-Jan-15 01:30:00          282.4272766     70.54191589
# 4       01-Jan-15 02:00:00          282.7499695      69.8094635
# 5       01-Jan-15 02:30:00          279.1145325     69.92195892
# 6       01-Jan-15 03:00:00          279.1595764     70.19512939
# 7       01-Jan-15 03:30:00          279.2045898     68.69129944
# 8       01-Jan-15 04:00:00          277.1072693     69.51984406
# 9       01-Jan-15 04:30:00          277.1288147     70.72741699
# 10      01-Jan-15 05:00:00          277.1503601     70.82144165
# 11      01-Jan-15 05:30:00           277.250885     69.11187744
# 12      01-Jan-15 06:00:00          277.0450439     70.09533691
# 13      01-Jan-15 06:30:00          276.8391724     70.26158905
# ...

# %%
#Takes a long time to run
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.convert_objects(convert_numeric=True)

# %%
df.tail()
# Out:
#                       Date  Autoclave Total Feed  Autoclave Level  \
# 202740 2017-07-21 12:30:00            149.271179        66.539337
# 202741 2017-07-21 13:00:00            149.262924        67.785484
# 202742 2017-07-21 13:30:00            149.254669        67.541000
# 202743 2017-07-21 14:00:00            149.246429        66.680656
# 202744 2017-07-21 14:30:00            149.238174        66.731705
#
#         Autoclave Vent Valve Position  Autoclave Pressure  \
# 202740                      11.268601         3088.155518
# 202741                      11.098818         3087.452393
# 202742                      10.929035         3089.176270
# 202743                      10.759252         3088.498047
# 202744                      10.589469         3088.878906
#
#         Compartment A O2 Flow  Compartment B O2 Flow  Compartment C O2 Flow  \
# 202740               8.233690               9.575311               6.040329
# ...

# %%
df = df.sort_values('Date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179063 entries, 0 to 97429
# Data columns (total 49 columns):
# Date                                   179063 non-null datetime64[ns]
# Autoclave Total Feed                   179063 non-null float64
# Autoclave Level                        179027 non-null float64
# Autoclave Vent Valve Position          165797 non-null float64
# Autoclave Pressure                     178769 non-null float64
# Compartment A O2 Flow                  161458 non-null float64
# Compartment B O2 Flow                  179027 non-null float64
# Compartment C O2 Flow                  179027 non-null float64
# Compartment D O2 Flow                  179018 non-null float64
# Agitator A Vibration                   168726 non-null float64
# Agitator B Vibration                   164807 non-null float64
# Agitator C Vibration                   137353 non-null float64
# Agitator D Vibration                   166388 non-null float64
# ...

# %%
timeseries = df.set_index('Date')

# %%
timeseries.head()
# Out:
#                      Autoclave Total Feed  Autoclave Level  \
# Date
# 2015-01-01 00:00:00            282.495941        72.699875
# 2015-01-01 00:00:00            282.495941        72.699875
# 2015-01-01 00:00:00            282.241547        71.789345
# 2015-01-01 00:00:00            253.500595        69.777382
# 2015-01-01 00:30:00            282.284332        69.616455
#
#                      Autoclave Vent Valve Position  Autoclave Pressure  \
# Date
# 2015-01-01 00:00:00                      66.980743         3071.238770
# 2015-01-01 00:00:00                      66.980743         3071.238770
# 2015-01-01 00:00:00                      10.442406         2993.305176
# 2015-01-01 00:00:00                      43.374519         2967.486328
# 2015-01-01 00:30:00                      63.633286         2972.379883
#
#                      Compartment A O2 Flow  Compartment B O2 Flow  \
# Date
# 2015-01-01 00:00:00              10.104209               9.413197
# ...

# %%
timeseries_vibration_feed = timeseries[['Agitator A Vibration', 'Agitator B Vibration', 'Agitator C Vibration', 'Agitator D Vibration', 'Agitator E Vibration', 'Agitator F Vibration', 'Agitator G Vibration']].loc[timeseries['AUT'] == 350]
import datetime

# %%
ts_vib = timeseries_vibration_feed[timeseries_vibration_feed.index > datetime.datetime(2016,11,1)]
ts_vib = ts_vib[ts_vib.index < datetime.datetime(2016,11,20)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
plt.plot(ts_vib);

# %%
small_ts = timeseries_total_feed.head(100)
# Out:
#   File "<ipython-input-18-6832747c71f0>", line 1
#     small_ts = timeseries_total_feed.head(50:100)
#                                             ^
# SyntaxError: invalid syntax

# %%
plt.plot(small_ts);

# %%
timeseries_150_temp_A = timeseries['Agitator A Temperature'].loc[timeseries['AUT'] == 150]

# %%
plt.plot(timeseries_150_temp_A);

# %%
small_ts_temp = timeseries_150_temp_A.head(5000)

# %%
plt.plot(small_ts_temp);

# %%
timeseries_vib_250 = timeseries['Agitator C Vibration'].loc[timeseries['AUT'] == 250]

# %%
plt.plot(timeseries_vib_250);

# %%
timeseries_cooling_250 = timeseries['Agitator C Cooling Water'].loc[timeseries['AUT'] == 250]

# %%
plt.plot(timeseries_cooling_250);
